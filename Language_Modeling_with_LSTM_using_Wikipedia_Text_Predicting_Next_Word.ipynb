# %% [markdown]
# ## Detailed article explaination
#
# The detailed code explanation for this article is available at the following link:
#
# https://www.daniweb.com/programming/computer-science/tutorials/540959/language-modeling-with-lstm-using-wikipedia-text-predicting-next-word
#
# For my other articles for Daniweb.com, please see this link:
#
# https://www.daniweb.com/members/1235222/usmanmalik57

# %%
## Import Wikipedia Data

# %%
! pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (4.11.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia) (2.5)

# %%
import wikipedia
pages = wikipedia.search("Artificial Intelligence")
pages
# Out:
# ['Artificial intelligence',
#  'Generative artificial intelligence',
#  'Artificial general intelligence',
#  'A.I. Artificial Intelligence',
#  'Applications of artificial intelligence',
#  'Hallucination (artificial intelligence)',
#  'Ethics of artificial intelligence',
#  'History of artificial intelligence',
#  'Swarm intelligence',
#  'Friendly artificial intelligence']

# %%
pages = wikipedia.search("Artificial Intelligence", results = 1)
pages
# Out:
# ['Artificial intelligence']

# %%
ai_page = wikipedia.page(pages[0])
print(ai_page.title)
# Out:
# Artificial intelligence

# %%
ai_page.content
# Out:
# 'Artificial intelligence (AI) is the intelligence of machines or software, as opposed to the intelligence of humans or animals. It is also the field of study in computer science that develops and studies intelligent machines. "AI" may also refer to the machines themselves.\nAI technology is widely used throughout industry, government and science. Some high-profile applications are: advanced web search engines (e.g., Google Search), recommendation systems (used by YouTube, Amazon, and Netflix), understanding human speech (such as Siri and Alexa), self-driving cars (e.g., Waymo), generative or creative tools (ChatGPT and AI art), and competing at the highest level in strategic games (such as chess and Go).Artificial intelligence was founded as an academic discipline in 1956. The field went through multiple cycles of optimism followed by disappointment and loss of funding, but after 2012, when deep learning surpassed all previous AI techniques, there was a vast increase in funding and interest.\nThe various sub-fields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include reasoning, knowledge representation, planning, learning, natural language processing, perception, and support for robotics. General intelligence (the ability to solve an arbitrary problem) is among the field\'s long-term goals.\nTo solve these problems, AI researchers have adapted and integrated a wide range of problem-solving techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics. AI also draws upon psychology, linguistics, philosophy, neuroscience and many other fields.\n\n\n== Goals ==\nThe general problem of simulating (or creating) intelligence has been broken down into sub-problems. These consist of particular traits or capabilities that researchers expect an intelligent system to display. The traits described below have received the most attention and cover the scope of AI research.\n\n\n=== Reasoning, problem-solving ===\nEarly researchers developed algorithms that imitated step-by-step reasoning that humans use when they solve puzzles or make logical deductions. By the late 1980s and 1990s, methods were developed for dealing with uncertain or incomplete information, employing concepts from probability and economics.Many of these algorithms are insufficient for solving large reasoning problems because they experience a "combinatorial explosion": they became exponentially slower as the problems grew larger.\nEven humans rarely use the step-by-step deduction that early AI research could model. They solve most of their problems using fast, intuitive judgments.\nAccurate and efficient reasoning is an unsolved problem.\n\n\n=== Knowledge representation ===\nKnowledge representation and knowledge engineering allow AI programs to answer questions intelligently and make deductions about real-world facts. Formal knowledge representations are used in content-based indexing and retrieval, scene interpretation, clinical decision support, knowledge discovery (mining "interesting" and actionable inferences from large databases), and other areas.A knowledge base is a body of knowledge represented in a form that can be used by a program. An ontology is the set of objects, relations, concepts, and properties used by a particular domain of knowledge. Knowledge bases need to represent things such as:\nobjects, properties, categories and relations between objects;\n\nsituations, events, states and time;\ncauses and effects;\nknowledge about knowledge (what we know about what other people know);default reasoning (things that humans assume are true until they are told differently and will remain true even when other facts are changing); and many other aspects and domains of knowledge.\nAmong the most difficult problems in KR are: the breadth of commonsense knowledge (the set of atomic fact ...

# %% [markdown]
# ## Preprocessing Text for LSTM

# %%
import re

# Split the text into sentences using '\n' as the separator
sentences = ai_page.content.split('\n')

# Function to remove special characters from a sentence
def remove_special_characters(sentence):
    return re.sub(r'[^\w\s]', '', sentence)

# Filter sentences with at least two words
sentences = [sentence.strip() for sentence in sentences if len(remove_special_characters(sentence).split()) >= 2]

# Printing length of total sentences
print(f"Total number of sentences: {len(sentences)}")

sentences[0]
# Out:
# Total number of sentences: 224
# 'Artificial intelligence (AI) is the intelligence of machines or software, as opposed to the intelligence of humans or animals. It is also the field of study in computer science that develops and studies intelligent machines. "AI" may also refer to the machines themselves.'

# %%
from keras.preprocessing.text import Tokenizer

# Create a tokenizer instance
tokenizer = Tokenizer()

# Fit the tokenizer on the text data
tokenizer.fit_on_texts(sentences)

# Print the word index (word to integer mapping)
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'of': 3,
#  'to': 4,
#  'a': 5,
#  'in': 6,
#  'that': 7,
#  'ai': 8,
#  'is': 9,
#  'as': 10,
#  'for': 11,
#  'are': 12,
#  'by': 13,
#  'or': 14,
#  'it': 15,
#  'intelligence': 16,
#  'be': 17,
#  'learning': 18,
#  'artificial': 19,
#  'can': 20,
#  'with': 21,
#  'an': 22,
#  'machine': 23,
#  'on': 24,
#  'not': 25,
#  'they': 26,
#  'such': 27,
#  'this': 28,
#  'have': 29,
#  'used': 30,
#  'was': 31,
#  'from': 32,
#  'human': 33,
#  'problems': 34,
#  'has': 35,
#  'knowledge': 36,
#  'these': 37,
#  'other': 38,
#  'use': 39,
#  'most': 40,
#  'research': 41,
#  'networks': 42,
#  'many': 43,
#  'may': 44,
#  'search': 45,
#  'problem': 46,
#  'at': 47,
#  'neural': 48,
#  'been': 49,
#  'will': 50,
#  'if': 51,
#  'were': 52,
#  'data': 53,
#  'reasoning': 54,
#  'about': 55,
#  'what': 56,
#  'also': 57,
#  'deep': 58,
#  'researchers': 59,
#  'decision': 60,
#  'general': 61,
#  'including': 62,
#  'machines': 63,
#  'technology': 64,
#  'solve': 65,
#  'make': 66,
#  'their': 67,
#  '–': 68,
#  'had': 69,
#  'applications': 70,
#  'when': 71,
#  'there': 72,
#  'program': 73,
#  'possible': 74,
#  'then': 75,
#  'which': 76,
#  'example': 77,
#  'more': 78,
#  'than': 79,
#  'risk': 80,
#  'field': 81,
#  'computer': 82,
#  'but': 83,
#  'information': 84,
#  'could': 85,
#  'agent': 86,
#  'would': 87,
#  'however': 88,
#  'mind': 89,
#  'some': 90,
#  'based': 91,
#  'algorithms': 92,
#  'using': 93,
#  'programs': 94,
#  'world': 95,
#  'people': 96,
#  'each': 97,
#  'intelligent': 98,
#  'systems': 99,
#  'logic': 100,
#  'system': 101,
#  'large': 102,
#  'symbolic': 103,
#  'specific': 104,
#  'how': 105,
#  'several': 106,
#  'humans': 107,
#  'all': 108,
#  'goals': 109,
#  'methods': 110,
#  'into': 111,
#  'between': 112,
#  'its': 113,
#  'theory': 114,
#  'input': 115,
#  'two': 116,
#  '2023': 117,
#  'algorithm': 118,
#  'like': 119,
#  'e': 120,
#  'generative': 121,
#  'processing': 122,
#  'ability': 123,
#  'developed': 124,
#  'form': 125,
#  'we': 126,
#  'making': 127,
#  'goal': 128,
#  'called': 129,
#  'action': 130,
#  'future': 131,
#  'so': 132,
#  'process': 133,
#  'where': 134,
#  'one': 135,
#  'recognition': 136,
#  'solutions': 137,
#  'no': 138,
#  'risks': 139,
#  'study': 140,
#  'widely': 141,
#  'google': 142,
#  'tools': 143,
#  'language': 144,
#  'term': 145,
#  'early': 146,
#  'because': 147,
#  'even': 148,
#  'real': 149,
#  'difficult': 150,
#  'modern': 151,
#  'who': 152,
#  'work': 153,
#  'does': 154,
#  'models': 155,
#  'them': 156,
#  'number': 157,
#  'any': 158,
#  'way': 159,
#  'decisions': 160,
#  'first': 161,
#  'question': 162,
#  'others': 163,
#  'began': 164,
#  'uses': 165,
#  'computing': 166,
#  'should': 167,
#  'only': 168,
#  'important': 169,
#  'well': 170,
#  '2016': 171,
#  'rather': 172,
#  'bias': 173,
#  'same': 174,
#  'software': 175,
#  'through': 176,
#  'sub': 177,
#  'include': 178,
#  'optimization': 179,
#  'formal': 180,
#  'misinformation': 181,
#  'must': 182,
#  'see': 183,
#  'learned': 184,
#  'state': 185,
#  'behavior': 186,
#  'new': 187,
#  'image': 188,
#  'processes': 189,
#  'inference': 190,
#  'identify': 191,
#  'fairness': 192,
#  'u': 193,
#  's': 194,
#  'both': 195,
#  'issue': 196,
#  'do': 197,
#  'us': 198,
#  'g': 199,
#  'level': 200,
#  'go': 201,
#  'techniques': 202,
#  'increase': 203,
#  'particular': 204,
#  'planning': 205,
#  'perception': 206,
#  'robotics': 207,
#  'solving': 208,
#  'became': 209,
#  'know': 210,
#  'actions': 211,
#  'choose': 212,
#  'especially': 213,
#  'agents': 214,
#  'find': 215,
#  'neurons': 216,
#  'whether': 217,
#  'outputs': 218,
#  'network': 219,
#  'potential': 220,
#  'privacy': 221,
#  'experts': 222,
#  '2022': 223,
#  'tasks': 224,
#  'science': 225,
#  'high': 226,
#  'advanced': 227,
#  'speech': 228,
#  'academic': 229,
#  'funding': 230,
#  'representation': 231,
#  'philosophy': 232,
#  'step': 233,
#  'uncertain': 234,
#  'situations': 235,
#  'states': 236,
#  'true': 237,
#  'until': 238,
#  'person': 239,
#  'companies': 240,
#  'space': 241,
#  'while': 242,
#  'policy': 243,
#  'classification': 244,
#  'inspired': 245,
#  'able': 246,
#  'users': 247,
#  'related': 248,
#  'local': 249,
#  'classifiers': 250,
#  'right': 251,
#  'training': 252,
#  'layers': 253,
#  'he': 254,
#  'race': 255,
#  'argued': 256,
#  'jobs': 257,
#  'automation': 258,
#  'robot': 259,
#  'physical': 260,
#  'laws': 261,
#  'rights': 262,
#  'government': 263,
#  'multiple': 264,
#  'after': 265,
#  'mathematical': 266,
#  'described': 267,
#  'logical': 268,
#  '1990s': 269,
#  'content': 270,
#  'set': 271,
#  'objects': 272,
#  'time': 273,
#  'domains': 274,
#  'known': 275,
#  'utility': 276,
#  'exactly': 277,
#  'certain': 278,
#  'function': 279,
#  'game': 280,
#  'part': 281,
#  'makes': 282,
#  'learn': 283,
#  'classified': 284,
#  'inputs': 285,
#  'trained': 286,
#  'similar': 287,
#  'very': 288,
#  'different': 289,
#  'simple': 290,
#  'solution': 291,
#  'powerful': 292,
#  'discovered': 293,
#  'specialized': 294,
#  'require': 295,
#  'i': 296,
#  'russell': 297,
#  'successful': 298,
#  'features': 299,
#  'success': 300,
#  '2010s': 301,
#  'since': 302,
#  'years': 303,
#  'widespread': 304,
#  'become': 305,
#  'harm': 306,
#  'developers': 307,
#  'still': 308,
#  'terms': 309,
#  'his': 310,
#  'area': 311,
#  'black': 312,
#  'past': 313,
#  'explain': 314,
#  'weapons': 315,
#  'existential': 316,
#  'fiction': 317,
#  'consciousness': 318,
#  'superintelligence': 319,
#  'approaches': 320,
#  'turing': 321,
#  '1960s': 322,
#  'approach': 323,
#  'soft': 324,
#  'easy': 325,
#  'feel': 326,
#  'industry': 327,
#  'amazon': 328,
#  'understanding': 329,
#  'self': 330,
#  'games': 331,
#  'chess': 332,
#  'founded': 333,
#  'previous': 334,
#  'around': 335,
#  'among': 336,
#  'long': 337,
#  'wide': 338,
#  'range': 339,
#  'economics': 340,
#  'late': 341,
#  'concepts': 342,
#  'probability': 343,
#  'experience': 344,
#  'model': 345,
#  'allow': 346,
#  'facts': 347,
#  'discovery': 348,
#  'things': 349,
#  'much': 350,
#  'internet': 351,
#  'itself': 352,
#  'published': 353,
#  'agreed': 354,
#  'anything': 355,
#  'preferences': 356,
#  'situation': 357,
#  'measures': 358,
#  'probabilistic': 359,
#  'guess': 360,
#  'improve': 361,
#  'value': 362,
#  'being': 363,
#  'given': 364,
#  'beginning': 365,
#  'without': 366,
#  'computational': 367,
#  'required': 368,
#  'difficulty': 369,
#  'word': 370,
#  'sense': 371,
#  'common': 372,
#  'text': 373,
#  'analysis': 374,
#  'playing': 375,
#  'position': 376,
#  'made': 377,
#  'our': 378,
#  'statistical': 379,
#  'statement': 380,
#  'designed': 381,
#  'over': 382,
#  'design': 383,
#  'norvig': 384,
#  'output': 385,
#  'far': 386,
#  'amounts': 387,
#  'scale': 388,
#  'facebook': 389,
#  'autonomous': 390,
#  'survey': 391,
#  'reported': 392,
#  'show': 393,
#  'americans': 394,
#  'white': 395,
#  'serious': 396,
#  'ethics': 397,
#  'surveillance': 398,
#  'argue': 399,
#  'works': 400,
#  'john': 401,
#  'led': 402,
#  'biased': 403,
#  '2015': 404,
#  'compas': 405,
#  're': 406,
#  'showed': 407,
#  'thus': 408,
#  'reached': 409,
#  'produced': 410,
#  'passed': 411,
#  'unemployment': 412,
#  'computers': 413,
#  'agree': 414,
#  'humanity': 415,
#  'sentience': 416,
#  'argues': 417,
#  'ethical': 418,
#  'consider': 419,
#  'narrow': 420,
#  'thinking': 421,
#  'defined': 422,
#  'hard': 423,
#  'business': 424,
#  'beings': 425,
#  'recommendation': 426,
#  'youtube': 427,
#  'driving': 428,
#  'chatgpt': 429,
#  'vast': 430,
#  'fields': 431,
#  'natural': 432,
#  'support': 433,
#  'upon': 434,
#  'creating': 435,
#  'below': 436,
#  'received': 437,
#  'incomplete': 438,
#  'exponentially': 439,
#  'rarely': 440,
#  'deduction': 441,
#  'unsolved': 442,
#  'engineering': 443,
#  'base': 444,
#  'body': 445,
#  'relations': 446,
#  'commonsense': 447,
#  'statements': 448,
#  'obtaining': 449,
#  'happen': 450,
#  'weighted': 451,
#  'occur': 452,
#  'effect': 453,
#  'typically': 454,
#  'take': 455,
#  'markov': 456,
#  'describes': 457,
#  'performance': 458,
#  'kinds': 459,
#  'patterns': 460,
#  'predictions': 461,
#  'predict': 462,
#  'deduce': 463,
#  'numeric': 464,
#  'good': 465,
#  'bad': 466,
#  'gained': 467,
#  'complexity': 468,
#  'allows': 469,
#  'often': 470,
#  'another': 471,
#  'analyze': 472,
#  'includes': 473,
#  'object': 474,
#  'social': 475,
#  'simulate': 476,
#  'actually': 477,
#  'searches': 478,
#  'tree': 479,
#  'target': 480,
#  'means': 481,
#  'result': 482,
#  'help': 483,
#  'choices': 484,
#  'likely': 485,
#  'reach': 486,
#  'landscape': 487,
#  'keep': 488,
#  'guesses': 489,
#  'generation': 490,
#  'swarm': 491,
#  'popular': 492,
#  'proving': 493,
#  'rule': 494,
#  'short': 495,
#  '1': 496,
#  'complex': 497,
#  'bayesian': 498,
#  'finding': 499,
#  'up': 500,
#  'pattern': 501,
#  'match': 502,
#  'examples': 503,
#  'observation': 504,
#  'class': 505,
#  'k': 506,
#  'brain': 507,
#  'n': 508,
#  'list': 509,
#  'next': 510,
#  'increasing': 511,
#  'according': 512,
#  'during': 513,
#  'back': 514,
#  'higher': 515,
#  'datasets': 516,
#  'hardware': 517,
#  'central': 518,
#  'commercial': 519,
#  'institutions': 520,
#  '2017': 521,
#  'test': 522,
#  '4': 523,
#  'held': 524,
#  '2020': 525,
#  'identified': 526,
#  'video': 527,
#  'those': 528,
#  'necessary': 529,
#  'view': 530,
#  'wrote': 531,
#  'copyrighted': 532,
#  'images': 533,
#  'under': 534,
#  'market': 535,
#  'tended': 536,
#  'create': 537,
#  'writing': 538,
#  'geoffrey': 539,
#  'hinton': 540,
#  'job': 541,
#  'developing': 542,
#  'algorithmic': 543,
#  'introduced': 544,
#  'prevent': 545,
#  'within': 546,
#  'define': 547,
#  'feature': 548,
#  'although': 549,
#  'history': 550,
#  'name': 551,
#  'racist': 552,
#  'recommendations': 553,
#  'better': 554,
#  'transparency': 555,
#  'mistakes': 556,
#  'sources': 557,
#  'predicted': 558,
#  'second': 559,
#  'regulation': 560,
#  'established': 561,
#  'provides': 562,
#  'countries': 563,
#  'robots': 564,
#  'considered': 565,
#  'united': 566,
#  'governments': 567,
#  'development': 568,
#  'economists': 569,
#  'employment': 570,
#  'healthcare': 571,
#  'chinese': 572,
#  'becomes': 573,
#  'achieve': 574,
#  'philosopher': 575,
#  'stuart': 576,
#  'believe': 577,
#  'current': 578,
#  'global': 579,
#  'alignment': 580,
#  'principles': 581,
#  'j': 582,
#  'emerging': 583,
#  'adopted': 584,
#  'strategies': 585,
#  'thought': 586,
#  'directly': 587,
#  'capable': 588,
#  'increased': 589,
#  'definition': 590,
#  'discussion': 591,
#  'critics': 592,
#  'limits': 593,
#  'conscious': 594,
#  'proposed': 595,
#  'symbol': 596,
#  'vs': 597,
#  'considers': 598,
#  'computationalism': 599,
#  'technologies': 600,
#  'idea': 601,
#  'textbooks': 602,
#  'ed': 603,
#  'opposed': 604,
#  'develops': 605,
#  'studies': 606,
#  'throughout': 607,
#  'engines': 608,
#  'netflix': 609,
#  'siri': 610,
#  'alexa': 611,
#  'cars': 612,
#  'creative': 613,
#  'discipline': 614,
#  '1956': 615,
#  'followed': 616,
#  '2012': 617,
#  'interest': 618,
#  "field's": 619,
#  'statistics': 620,
#  'operations': 621,
#  'traits': 622,
#  'expect': 623,
#  'attention': 624,
#  'puzzles': 625,
#  'deductions': 626,
#  '1980s': 627,
#  'explosion': 628,
#  'fast': 629,
#  'accurate': 630,
#  'efficient': 631,
#  'questions': 632,
#  'intelligently': 633,
#  'retrieval': 634,
#  'areas': 635,
#  'represented': 636,
#  'properties': 637,
#  'need': 638,
#  'events': 639,
#  'default': 640,
#  'assume': 641,
#  'told': 642,
#  'changing': 643,
#  'aspects': 644,
#  'breadth': 645,
#  'knows': 646,
#  'enormous': 647,
#  'express': 648,
#  'professionals': 649,
#  'technique': 650,
#  'correct': 651,
#  'highly': 652,
#  'takes': 653,
#  'rational': 654,
#  'automated': 655,
#  'avoid': 656,
#  'assigns': 657,
#  'expected': 658,
#  'outcome': 659,
#  'maximum': 660,
#  'reinforcement': 661,
#  'exploratory': 662,
#  'experimental': 663,
#  'cost': 664,
#  'finds': 665,
#  'supervised': 666,
#  'requires': 667,
#  'comes': 668,
#  'main': 669,
#  'responses': 670,
#  'ones': 671,
#  'types': 672,
#  'assess': 673,
#  'sample': 674,
#  'nlp': 675,
#  'languages': 676,
#  'english': 677,
#  'translation': 678,
#  'answering': 679,
#  'noam': 680,
#  'restricted': 681,
#  'due': 682,
#  'appears': 683,
#  'near': 684,
#  'gpt': 685,
#  'get': 686,
#  'sensors': 687,
#  'signals': 688,
#  'vision': 689,
#  'facial': 690,
#  'robotic': 691,
#  'affective': 692,
#  'recognize': 693,
#  'virtual': 694,
#  'assistants': 695,
#  'programmed': 696,
#  'interaction': 697,
#  'successes': 698,
#  'sentiment': 699,
#  'subject': 700,
#  'variety': 701,
#  'above': 702,
#  'try': 703,
#  'path': 704,
#  'sufficient': 705,
#  'numbers': 706,
#  'too': 707,
#  'never': 708,
#  'moves': 709,
#  'looking': 710,
#  'blind': 711,
#  'hill': 712,
#  'begin': 713,
#  'steps': 714,
#  'computation': 715,
#  'survive': 716,
#  'distributed': 717,
#  'ant': 718,
#  'discussed': 719,
#  'operates': 720,
#  'premises': 721,
#  'handles': 722,
#  'case': 723,
#  'valid': 724,
#  'application': 725,
#  'intractable': 726,
#  'fuzzy': 727,
#  'truth': 728,
#  '0': 729,
#  'uncertainty': 730,
#  'handle': 731,
#  'versions': 732,
#  'devised': 733,
#  'dynamic': 734,
#  'precise': 735,
#  'simplest': 736,
#  'divided': 737,
#  'diamond': 738,
#  'hand': 739,
#  'determine': 740,
#  'nearest': 741,
#  'neighbor': 742,
#  'classifier': 743,
#  'neuron': 744,
#  'weights': 745,
#  'matrix': 746,
#  'layer': 747,
#  'backpropagation': 748,
#  'relationships': 749,
#  'signal': 750,
#  'recurrent': 751,
#  'perceptrons': 752,
#  'convolutional': 753,
#  'before': 754,
#  'relevant': 755,
#  'digits': 756,
#  'improved': 757,
#  'reason': 758,
#  'did': 759,
#  'theoretical': 760,
#  '1950s': 761,
#  'factors': 762,
#  'power': 763,
#  'speed': 764,
#  'gpus': 765,
#  'curated': 766,
#  'testing': 767,
#  'imagenet': 768,
#  'graphics': 769,
#  'units': 770,
#  'lisp': 771,
#  'essential': 772,
#  '2020s': 773,
#  'online': 774,
#  'microsoft': 775,
#  "apple's": 776,
#  'face': 777,
#  'labeling': 778,
#  'thousands': 779,
#  'few': 780,
#  'medical': 781,
#  'blue': 782,
#  'beat': 783,
#  'champion': 784,
#  'jeopardy': 785,
#  'defeated': 786,
#  'becoming': 787,
#  'professional': 788,
#  'own': 789,
#  'trend': 790,
#  'generated': 791,
#  'photos': 792,
#  'demonstrated': 793,
#  'hours': 794,
#  'benefits': 795,
#  'advance': 796,
#  'demis': 797,
#  'hassabis': 798,
#  'hopes': 799,
#  'copyright': 800,
#  'concerns': 801,
#  'audio': 802,
#  'order': 803,
#  'build': 804,
#  'allowed': 805,
#  'opinions': 806,
#  'clearly': 807,
#  'valuable': 808,
#  "'what": 809,
#  'doing': 810,
#  'rationale': 811,
#  'disagree': 812,
#  'courts': 813,
#  'law': 814,
#  'character': 815,
#  'leading': 816,
#  'watching': 817,
#  'extreme': 818,
#  'trust': 819,
#  'major': 820,
#  'films': 821,
#  'actors': 822,
#  'propaganda': 823,
#  'expressed': 824,
#  'exists': 825,
#  'seriously': 826,
#  'medicine': 827,
#  'cause': 828,
#  'caused': 829,
#  'june': 830,
#  'gorilla': 831,
#  'later': 832,
#  'products': 833,
#  'fact': 834,
#  'whites': 835,
#  'blacks': 836,
#  '61': 837,
#  'chance': 838,
#  'offend': 839,
#  'impossible': 840,
#  'gender': 841,
#  'highlighted': 842,
#  'misuse': 843,
#  'results': 844,
#  'hope': 845,
#  'necessarily': 846,
#  '20': 847,
#  'machinery': 848,
#  'presented': 849,
#  'amount': 850,
#  'expert': 851,
#  'cases': 852,
#  'tests': 853,
#  'nevertheless': 854,
#  'something': 855,
#  'intended': 856,
#  'ruler': 857,
#  'dangerous': 858,
#  'rich': 859,
#  'low': 860,
#  'further': 861,
#  'measured': 862,
#  'explanation': 863,
#  'explicit': 864,
#  'explainable': 865,
#  '2014': 866,
#  'addition': 867,
#  'produce': 868,
#  'weaponized': 869,
#  'lethal': 870,
#  'selects': 871,
#  'targets': 872,
#  'reasons': 873,
#  'kill': 874,
#  'clear': 875,
#  '30': 876,
#  'china': 877,
#  'convention': 878,
#  'useful': 879,
#  'authoritarian': 880,
#  'matter': 881,
#  'arguments': 882,
#  'done': 883,
#  'redundancies': 884,
#  'total': 885,
#  'generally': 886,
#  'benefit': 887,
#  'middle': 888,
#  'eliminated': 889,
#  'collar': 890,
#  'control': 891,
#  'stephen': 892,
#  'hawking': 893,
#  'gives': 894,
#  'almost': 895,
#  'sufficiently': 896,
#  'safe': 897,
#  'morality': 898,
#  'values': 899,
#  'stories': 900,
#  'concerned': 901,
#  'superintelligent': 902,
#  'joint': 903,
#  'priority': 904,
#  'friendly': 905,
#  '2005': 906,
#  'three': 907,
#  'provably': 908,
#  'beneficial': 909,
#  'public': 910,
#  'regulatory': 911,
#  'stanford': 912,
#  'alone': 913,
#  'india': 914,
#  'november': 915,
#  '2021': 916,
#  'regulate': 917,
#  'leaders': 918,
#  'less': 919,
#  'ipsos': 920,
#  '35': 921,
#  'poll': 922,
#  'additional': 923,
#  'responding': 924,
#  '8': 925,
#  'safety': 926,
#  'possibility': 927,
#  'philosophers': 928,
#  'antiquity': 929,
#  'alan': 930,
#  'algebra': 931,
#  'funded': 932,
#  'simon': 933,
#  'marvin': 934,
#  'minsky': 935,
#  'british': 936,
#  'projects': 937,
#  'book': 938,
#  'winter': 939,
#  'simulated': 940,
#  'analytical': 941,
#  'billion': 942,
#  'project': 943,
#  'longer': 944,
#  'focussed': 945,
#  'move': 946,
#  '21st': 947,
#  'century': 948,
#  'verifiable': 949,
#  'mathematics': 950,
#  "learning's": 951,
#  'publications': 952,
#  '50': 953,
#  'issues': 954,
#  'stage': 955,
#  'thinks': 956,
#  'notes': 957,
#  'pigeons': 958,
#  'founder': 959,
#  'mccarthy': 960,
#  'defines': 961,
#  'definitions': 962,
#  'philosophical': 963,
#  'eventually': 964,
#  'why': 965,
#  'attempts': 966,
#  'neats': 967,
#  'scruffies': 968,
#  '80s': 969,
#  'irrelevant': 970,
#  'external': 971,
#  'subjective': 972,
#  'red': 973,
#  'relationship': 974,
#  'searle': 975,
#  'suffer': 976,
#  'hypothetical': 977,
#  'singularity': 978,
#  'kevin': 979,
#  'edward': 980,
#  'culture': 981,
#  "asimov's": 982,
#  'r': 983,
#  'dick': 984,
#  'arms': 985,
#  'emergent': 986,
#  'isbn': 987,
#  '978': 988,
#  'encyclopedia': 989,
#  'animals': 990,
#  'refer': 991,
#  'themselves': 992,
#  'profile': 993,
#  'web': 994,
#  'waymo': 995,
#  'art': 996,
#  'competing': 997,
#  'highest': 998,
#  'strategic': 999,
#  'went': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index)
print(vocab_size)
# Out:
# 2472

# %%
# Convert text to integers using the tokenizer
int_sequences = tokenizer.texts_to_sequences(sentences)
int_sequences[0]
# Out:
# [19,
#  16,
#  8,
#  9,
#  1,
#  16,
#  3,
#  63,
#  14,
#  175,
#  10,
#  604,
#  4,
#  1,
#  16,
#  3,
#  107,
#  14,
#  990,
#  15,
#  9,
#  57,
#  1,
#  81,
#  3,
#  140,
#  6,
#  82,
#  225,
#  7,
#  605,
#  2,
#  606,
#  98,
#  63,
#  8,
#  44,
#  57,
#  991,
#  4,
#  1,
#  63,
#  992]

# %%
processed_sequences = []

for inp_sequence in int_sequences:
  temp_list = inp_sequence[:2]
  processed_sequences.append(temp_list.copy())

  for item in inp_sequence[2:]:
      temp_list.append(item)
      processed_sequences.append(temp_list.copy())

# %%
processed_sequences[0], processed_sequences[1], processed_sequences[2]
# Out:
# ([19, 16], [19, 16, 8], [19, 16, 8, 9])

# %%
# Extract features (X) and labels (Y) using list comprehensions
X = [sequence[:-1] for sequence in processed_sequences]  # Features (excluding the last item in each internal list)
y = [sequence[-1] for sequence in processed_sequences]    # Labels (only the last item in each internal list)

# %%
print(f"First 3 sequences: {processed_sequences[0], processed_sequences[1], processed_sequences[2]}")
print(f"Features list:  {X[0], X[1], X[2]}")
print(f"Labels list: {y[0], y[1], y[2]}")
# Out:
# First 3 sequences: ([19, 16], [19, 16, 8], [19, 16, 8, 9])
# Features list:  ([19], [19, 16], [19, 16, 8])
# Labels list: (16, 8, 9)

# %%
# Find the length of the longest sentence. Will use this for padding
max_length = max(len(internal_list) for internal_list in X)
max_length
# Out:
# 552

# %%
from keras.preprocessing.sequence import pad_sequences

# Apply pre-padding to processed_sequences using pad_sequences function
X = pad_sequences(X, maxlen=max_length, padding='pre')

# %%
from keras.utils import to_categorical

y = to_categorical(y, num_classes = vocab_size + 1)

# %%
print(f"{X.shape, y.shape}")
# Out:
# ((9136, 552), (9136, 2473))

# %% [markdown]
# ## Training an LSTM Model

# %%
from keras.models import Model
from keras.layers import Embedding, LSTM, Dense, Input


def get_model():
  # Define the input shape (sequence length)
  input_shape = (max_length,)

  # Input layer
  input_layer = Input(shape=input_shape)

  # Embedding layer
  embedding_size = 100  # Example embedding size, adjust according to your use case
  embedding_layer = Embedding(input_dim = vocab_size +1,
                              output_dim = 100,
                              input_length =max_length)(input_layer)

  # LSTM layer
  lstm_1 = LSTM(500)(embedding_layer)

  # Output layer with softmax activation
  output_layer = Dense(vocab_size + 1,
                      activation='softmax',
                      name='output_layer')(lstm_1)

  # Create the model
  model = Model(inputs=input_layer, outputs=output_layer)

  # Compile the model with Adam optimizer, categorical cross-entropy loss, and accuracy metric
  model.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

  return model

model = get_model()
# Print the model summary
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 552)]             0
#
#  embedding_1 (Embedding)     (None, 552, 100)          247300
#
#  lstm_1 (LSTM)               (None, 500)               1202000
#
#  output_layer (Dense)        (None, 2473)              1238973
#
# =================================================================
# Total params: 2688273 (10.25 MB)
# Trainable params: 2688273 (10.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fit the model using X_train and y_train
model.fit(X, y,
          epochs = 30
          )
# Out:
# Epoch 1/30
# 286/286 [==============================] - 32s 105ms/step - loss: 6.9120 - accuracy: 0.0435
# Epoch 2/30
# 286/286 [==============================] - 20s 69ms/step - loss: 6.4261 - accuracy: 0.0594
# Epoch 3/30
# 286/286 [==============================] - 16s 58ms/step - loss: 6.1762 - accuracy: 0.0719
# Epoch 4/30
# 286/286 [==============================] - 15s 52ms/step - loss: 5.8664 - accuracy: 0.0836
# Epoch 5/30
# 286/286 [==============================] - 13s 46ms/step - loss: 5.4118 - accuracy: 0.0991
# Epoch 6/30
# 286/286 [==============================] - 13s 45ms/step - loss: 4.7435 - accuracy: 0.1326
# Epoch 7/30
# 286/286 [==============================] - 12s 43ms/step - loss: 3.8922 - accuracy: 0.2034
# Epoch 8/30
# 286/286 [==============================] - 13s 45ms/step - loss: 2.9556 - accuracy: 0.3632
# Epoch 9/30
# 286/286 [==============================] - 12s 41ms/step - loss: 2.0774 - accuracy: 0.5605
# Epoch 10/30
# 286/286 [==============================] - 12s 43ms/step - loss: 1.3876 - accuracy: 0.7320
# Epoch 11/30
# 286/286 [==============================] - 12s 42ms/step - loss: 0.8874 - accuracy: 0.8511
# Epoch 12/30
# 286/286 [==============================] - 12s 41ms/step - loss: 0.5546 - accuracy: 0.9228
# Epoch 13/30
# 286/286 [==============================] - 12s 41ms/step - loss: 0.3490 - accuracy: 0.9573
# Epoch 14/30
# 286/286 [==============================] - 12s 41ms/step - loss: 0.2320 - accuracy: 0.9697
# Epoch 15/30
# 286/286 [==============================] - 11s 40ms/step - loss: 0.1714 - accuracy: 0.9754
# Epoch 16/30
# 286/286 [==============================] - 11s 40ms/step - loss: 0.1455 - accuracy: 0.9773
# Epoch 17/30
# 286/286 [==============================] - 11s 39ms/step - loss: 1.4374 - accuracy: 0.7141
# Epoch 18/30
# 286/286 [==============================] - 12s 40ms/step - loss: 0.6468 - accuracy: 0.8876
# Epoch 19/30
# 286/286 [==============================] - 12s 40ms/step - loss: 0.4471 - accuracy: 0.9261
# Epoch 20/30
# 286/286 [==============================] - 12s 41ms/step - loss: 0.2176 - accuracy: 0.9641
# Epoch 21/30
# 286/286 [==============================] - 11s 40ms/step - loss: 0.1853 - accuracy: 0.9707
# Epoch 22/30
# 286/286 [==============================] - 12s 40ms/step - loss: 0.1284 - accuracy: 0.9777
# Epoch 23/30
# 286/286 [==============================] - 12s 42ms/step - loss: 0.1046 - accuracy: 0.9818
# Epoch 24/30
# 286/286 [==============================] - 11s 39ms/step - loss: 0.0900 - accuracy: 0.9838
# Epoch 25/30
# 286/286 [==============================] - 11s 40ms/step - loss: 0.0798 - accuracy: 0.9854
# Epoch 26/30
# 286/286 [==============================] - 12s 41ms/step - loss: 0.0801 - accuracy: 0.9846
# Epoch 27/30
# 286/286 [==============================] - 12s 40ms/step - loss: 0.0835 - accuracy: 0.9847
# Epoch 28/30
# 286/286 [==============================] - 11s 40ms/step - loss: 0.0673 - accuracy: 0.9859
# Epoch 29/30
# 286/286 [==============================] - 11s 40ms/step - loss: 0.0604 - accuracy: 0.9869
# Epoch 30/30
# 286/286 [==============================] - 11s 40ms/step - loss: 0.0572 - accuracy: 0.9871

# %%
# Import the necessary libraries
import numpy as np

# Define a function 'generate_text' that takes input text and the number of words to generate as parameters
def generate_text(input_text, num_gen):

  # Initialize the current input with the given input text
  current_input = input_text

  # Iterate 'num_gen' times to generate the specified number of words
  for i in range(num_gen):
    # Convert the current input text into tokenized form using the tokenizer
    tokenized_text = tokenizer.texts_to_sequences([current_input])[0]

    # Pad the tokenized text to match the required input length for the model
    padded_text = pad_sequences([tokenized_text],
                                maxlen=max_length,
                                padding='pre')

    # Use the model to predict the next word in the sequence
    prediction = model.predict(padded_text, verbose=0)

    # Get the index of the predicted word with the highest probability
    predicted_index = np.argmax(prediction)

    # Find the corresponding word for the predicted index using the tokenizer's word index
    predicted_word = []
    for word, index in tokenizer.word_index.items():
      if index == predicted_index:
        predicted_word = word
        break;

    # Add the predicted word to the current input for the next iteration
    current_input = current_input + " " + predicted_word

  # Return the generated text
  return current_input

# %%
input = "natural"
words_to_generate = 20
output = generate_text(input, words_to_generate)
output
# Out:
# 'natural language processing nlp allows programs to read write and communicate in human languages such as english and go had simulate'
